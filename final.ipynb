# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Ananya\Downloads\BATTING STATS - IPL_2022.csv')

# %%
df1=pd.read_csv(r'C:\Users\Ananya\Downloads\BOWLING STATS - IPL_2022.csv')

# %%
print(df.describe())
# Out:
#               Mat        Inns        Runs         Avg          BF          SR  \
# count  310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean     8.841935    6.687097  129.522581   18.074548   98.964516  112.979742
# std      5.082891    4.776781  155.508991   14.631810  112.626522   46.542809
# min      1.000000    1.000000    0.000000    0.000000    1.000000    0.000000
# 25%      4.000000    2.000000   13.000000    6.125000   13.000000   92.350000
# 50%      9.000000    5.000000   58.000000   15.875000   46.500000  118.455000
# 75%     14.000000   10.000000  213.500000   28.337500  159.000000  139.305000
# max     17.000000   17.000000  863.000000   75.660000  579.000000  400.000000
#
#               100          50          4s          6s
# count  310.000000  310.000000  310.000000  310.000000
# mean     0.032258    0.629032   11.354839    5.545161
# std      0.264865    1.188318   15.189096    7.123249
# ...

# %%
print("Maximum number of Matches played by an individual player in a season:", df["Mat"].max())
# Out:
# Maximum number of Matches played by an individual player in a season: 17

# %%
print("Highest Average of a player in a season:", df["Avg"].max())
# Out:
# Highest Average of a player in a season: 75.66

# %%
print("Average number of Matches played by a player in a season:", df["Mat"].mean())
# Out:
# Average number of Matches played by a player in a season: 8.841935483870968

# %%
century = df[(df["100"]) > 0]
print(century)
# Out:
#               Player  Mat  Inns  Runs    Avg   BF      SR  100  50  4s  6s
# 0        Jos Buttler   17    17   863  57.53  579  149.05    4   4  83  45
# 1    Ruturaj Gaikwad   16    16   635  45.35  466  136.26    1   4  64  23
# 6    Quinton De Kock   15    15   508  36.29  341  148.97    1   3  47  23
# 8       Sanju Samson   14    14   484  40.33  354  136.72    1   2  45  17
# 24  Devdutt Padikkal   14    14   411  31.61  328  125.30    1   1  44  14
# 40     Rajat Patidar    8     7   333  55.50  218  152.75    1   2  27  18
# 58       Jos Buttler    7     7   254  36.28  166  153.01    1   0  27  13

# %%
half_century = df[(df["50"]) > 3]
print(half_century)
# Out:
#               Player  Mat  Inns  Runs    Avg   BF      SR  100  50  4s  6s
# 0        Jos Buttler   17    17   863  57.53  579  149.05    4   4  83  45
# 1    Ruturaj Gaikwad   16    16   635  45.35  466  136.26    1   4  64  23
# 2     Faf du Plessis   16    16   633  45.21  458  138.20    0   6  60  23
# 3           KL Rahul   13    13   626  62.60  451  138.80    0   6  48  30
# 5      Glenn Maxwell   15    14   513  42.75  356  144.10    0   6  48  21
# 7      Hardik Pandya   15    15   487  44.27  371  131.26    0   4  49  12
# 9       Shubman Gill   16    16   483  34.50  365  132.32    0   4  51  11
# 11      Prithvi Shaw   15    15   479  31.93  301  159.13    0   4  56  18
# 16      Deepak Hooda   15    14   451  32.21  330  136.66    0   4  36  18
# 17    Mayank Agarwal   12    12   441  40.09  314  140.44    0   4  42  18
# 18  Liam Livingstone   14    14   437  36.42  240  182.08    0   4  29  34
# ...

# %%
boundaries = df[(df["4s"] > 45) & (df["6s"] > 10)]
print(boundaries)
# Out:
#              Player  Mat  Inns  Runs    Avg   BF      SR  100  50  4s  6s
# 0       Jos Buttler   17    17   863  57.53  579  149.05    4   4  83  45
# 1   Ruturaj Gaikwad   16    16   635  45.35  466  136.26    1   4  64  23
# 2    Faf du Plessis   16    16   633  45.21  458  138.20    0   6  60  23
# 3          KL Rahul   13    13   626  62.60  451  138.80    0   6  48  30
# 4    Shikhar Dhawan   16    16   587  39.13  471  124.62    0   3  63  16
# 5     Glenn Maxwell   15    14   513  42.75  356  144.10    0   6  48  21
# 6   Quinton De Kock   15    15   508  36.29  341  148.97    1   3  47  23
# 7     Hardik Pandya   15    15   487  44.27  371  131.26    0   4  49  12
# 9      Shubman Gill   16    16   483  34.50  365  132.32    0   4  51  11
# 11     Prithvi Shaw   15    15   479  31.93  301  159.13    0   4  56  18
# 12     Shubman Gill   17    17   478  28.11  402  118.90    0   3  50  12
# 13   Faf Du Plessis   16    16   468  31.20  367  127.52    0   3  49  13
# ...

# %%
f_most_runs_sort_by_matches = df.sort_values(by=['Mat'], ascending=False)
plt.figure(figsize=(20, 7))
sns.barplot(x=df["Mat"], y=df["Player"][:30], palette="gist_ncar")
# Out:
# C:\Users\Ananya\AppData\Local\Temp\ipykernel_23248\3944810420.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df["Mat"], y=df["Player"][:30], palette="gist_ncar")
# <Axes: xlabel='Mat', ylabel='Player'>

# %%
df_sort_by_matches = df.sort_values(by=['Runs'], ascending=False)
plt.figure(figsize=(20, 8))
sns.barplot(x=df["Runs"],y=df["Player"][:30],palette="Spectral")
# Out:
# C:\Users\Ananya\AppData\Local\Temp\ipykernel_23248\2314934737.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df["Runs"],y=df["Player"][:30],palette="Spectral")
# <Axes: xlabel='Runs', ylabel='Player'>

# %%
plt.figure(figsize=(12,6))
plt.plot(df["Player"][:10],df["Avg"][:10],color='tab:orange')

# %%
plt.figure(figsize=(12,6))
plt.plot(df["Player"][:10], df["SR"][:10],color='b')
plt.plot(df["Player"][:10],df["BF"][:10],color='g')

# %%
df_most_runs_SR = df.loc[:, ["Player", "SR"]]
df_most_runs_SR = df_most_runs_SR.sort_values(by=['SR'], ascending=False)
df_sort_by_matches = df.sort_values(by=['SR'], ascending=False)
plt.figure(figsize=(20, 8))
sns.barplot(x=df_most_runs_SR["SR"], y=df_most_runs_SR["Player"][:20], palette="Spectral")
# Out:
# C:\Users\Ananya\AppData\Local\Temp\ipykernel_23248\2557057499.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df_most_runs_SR["SR"], y=df_most_runs_SR["Player"][:20], palette="Spectral")
# <Axes: xlabel='SR', ylabel='Player'>

# %%
print(df1.describe())
# Out:
#               POS         Mat        Inns          Ov        Runs        Wkts  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000  103.000000
# mean    52.000000    8.815534    7.941748   27.166019  227.213592    8.242718
# std     29.877528    4.872386    4.764709   18.447714  146.147498    6.484470
# min      1.000000    1.000000    1.000000    0.300000    8.000000    1.000000
# 25%     26.500000    5.000000    4.000000   11.500000  100.500000    3.000000
# 50%     52.000000    9.000000    7.000000   23.000000  210.000000    6.000000
# 75%     77.500000   13.000000   12.000000   43.000000  349.500000   12.500000
# max    103.000000   17.000000   17.000000   68.000000  551.000000   27.000000
#
#               Avg        Econ          SR          4w          5w
# count  103.000000  103.000000  103.000000  103.000000  103.000000
# mean    33.685437    8.821262   23.226117    0.203883    0.038835
# std     15.984617    1.698188   11.030324    0.450691    0.194146
# ...

# %%
print("Maximum number of Matches played by an individual player in a season:", df1["Mat"].max())
# Out:
# Maximum number of Matches played by an individual player in a season: 17

# %%
print("Lowest Average of a player in a season:", df1["Avg"].min())
# Out:
# Lowest Average of a player in a season: 5.5

# %%
print("Average number of Matches played by a player in a season:", df1["Mat"].mean())
# Out:
# Average number of Matches played by a player in a season: 8.815533980582524

# %%
avg_Sr = df1[(df1["Wkts"] > 12) & (df1["SR"] < 23)]["Player"]
print(avg_Sr)
# Out:
# 0      Yuzvendra Chahal
# 1     Wanindu Hasaranga
# 2         Kagiso Rabada
# 3           Umran Malik
# 4         Kuldeep Yadav
# 5        Mohammad Shami
# 6        Josh Hazlewood
# 7           Rashid Khan
# 8         Harshal Patel
# 9       Prasidh Krishna
# 10           Avesh Khan
# 11          T Natarajan
# 12        Andre Russell
# 13          Umesh Yadav
# 15        Khaleel Ahmed
# 16         Dwayne Bravo
# 17     Mukesh Choudhary
# 18       Jasprit Bumrah
# 19       Shardul Thakur
# 20          Mohsin Khan
# 21         Rahul Chahar
# 22          Tim Southee
# 23         Jason Holder
# 25          Daniel Sams
# Name: Player, dtype: object

# %%
avg_sr_below = df1[(df1["Wkts"] > 8) & (df1["Ov"] > 27)]
print(avg_sr_below)
# Out:
#     POS               Player  Mat  Inns    Ov  Runs  Wkts   BBI    Avg   Econ  \
# 0     1     Yuzvendra Chahal   17    17  68.0   527    27  40/5  19.51   7.75
# 1     2    Wanindu Hasaranga   16    16  57.0   430    26  18/5  16.53   7.54
# 2     3        Kagiso Rabada   13    13  48.0   406    23  33/4  17.65   8.45
# 3     4          Umran Malik   14    14  49.1   444    22  25/5  20.18   9.03
# 4     5        Kuldeep Yadav   14    14  49.4   419    21  14/4  19.95   8.43
# 5     6       Mohammad Shami   16    16  61.0   488    20  25/3  24.40   8.00
# 6     7       Josh Hazlewood   12    12  46.3   377    20  25/4  18.85   8.10
# 7     8          Rashid Khan   16    16  63.5   421    19  24/4  22.15   6.59
# 8     9        Harshal Patel   15    15  53.3   410    19  34/4  21.57   7.66
# 9    10      Prasidh Krishna   17    17  66.3   551    19  22/3  29.00   8.28
# 10   11           Avesh Khan   13    13  47.4   416    18  24/4  23.11   8.72
# ...

# %%
run_avg_sr = df1[(df1["Ov"] > 40) & (df1["Wkts"] > 15) & (df1["Econ"] < 8)]
print(run_avg_sr)
# Out:
#     POS             Player  Mat  Inns    Ov  Runs  Wkts   BBI    Avg  Econ  \
# 0     1   Yuzvendra Chahal   17    17  68.0   527    27  40/5  19.51  7.75
# 1     2  Wanindu Hasaranga   16    16  57.0   430    26  18/5  16.53  7.54
# 7     8        Rashid Khan   16    16  63.5   421    19  24/4  22.15  6.59
# 8     9      Harshal Patel   15    15  53.3   410    19  34/4  21.57  7.66
# 13   14        Umesh Yadav   12    12  48.0   339    16  23/4  21.18  7.06
# 14   15        Trent Boult   16    16  62.0   492    16  18/2  30.75  7.93
#
#        SR  4w  5w
# 0   15.11   1   1
# 1   13.15   1   1
# 7   20.15   1   0
# 8   16.89   1   0
# 13  18.00   1   0
# 14  23.25   0   0

# %%
df1_most_runs_sort_by_matches = df1.sort_values(by=['Mat'], ascending=False)
plt.figure(figsize=(20, 7))
sns.barplot(x=df1["Mat"], y=df1["Player"][:30], palette="gist_ncar")
# Out:
# C:\Users\Ananya\AppData\Local\Temp\ipykernel_23248\2579874167.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df1["Mat"], y=df1["Player"][:30], palette="gist_ncar")
# <Axes: xlabel='Mat', ylabel='Player'>

# %%
x = df1["Wkts"]
y = df1["Mat"]
colors = df1["Wkts"]
sizes = 100 * df1["Wkts"]
plt.figure(figsize=(20, 7))
plt.scatter(x,y,c=colors,s=sizes,alpha=0.3,cmap='viridis')
plt.colorbar();

# %%
f1_sort_by_matches = df1.sort_values(by=['Runs'], ascending=False)
plt.figure(figsize=(20, 8))
sns.barplot(x=df1["Wkts"],y=df1["Player"][:30],palette="Spectral");
# Out:
# C:\Users\Ananya\AppData\Local\Temp\ipykernel_23248\1570454352.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df1["Wkts"],y=df1["Player"][:30],palette="Spectral");

# %%
plt.figure(figsize=(20, 6))
plt.plot(df1["Player"][:10],df1["Avg"][:10],color='tab:orange')
plt.plot(df1["Player"][:10],df1["SR"][:10],color='b'),plt.plot(df1["Player"][:10],df1["Ov"][:10],color='g')
# Out:
# ([<matplotlib.lines.Line2D at 0x2b914770410>],
#  [<matplotlib.lines.Line2D at 0x2b914772ab0>])

# %%
df1_most_runs_SR = df1.loc[:, ["Player", "SR"]]
df1_most_runs_SR = df1_most_runs_SR.sort_values(by=['SR'], ascending=False)
df1_sort_by_matches = df1.sort_values(by=['SR'], ascending=False)
plt.figure(figsize=(20, 8))
sns.barplot(x=df1_most_runs_SR["SR"], y=df1_most_runs_SR["Player"][:20], palette="Spectral")
# Out:
# C:\Users\Ananya\AppData\Local\Temp\ipykernel_20488\1807248034.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df1_most_runs_SR["SR"], y=df1_most_runs_SR["Player"][:20], palette="Spectral")
# <Axes: xlabel='SR', ylabel='Player'>
